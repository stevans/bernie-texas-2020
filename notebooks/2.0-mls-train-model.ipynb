# %%
import pandas as pd

# %%
#Read in all features
all_features = pd.read_csv('../data/interim/all_features.csv')

# %%
all_features
# Out:
#      population_2018  fraction_white_nh  fraction_hispanic  fraction_black  \
# 0              29565           0.626585           0.178759        0.088821
# 1                595           0.121008           0.842017        0.000000
# 2             360486           0.298630           0.600706        0.037782
# 3              21022           0.563933           0.172391        0.126772
# 4              11473           0.855400           0.048636        0.028066
# ..               ...                ...                ...             ...
# 232             8098           0.610645           0.225117        0.018276
# 233            16952           0.635500           0.160453        0.112258
# 234           168838           0.616810           0.196715        0.097223
# 235            51365           0.690821           0.202901        0.015361
# 236            17299           0.513209           0.208740        0.243482
#
#      fraction_other_race  fraction_w4yrdeg  per_capita_income  \
# ...

# %%
all_features['delta_fraction_sanders'] = all_features['fraction_sanders_2020'] - \
        all_features['fraction_sanders_2016']

# %%
columns_to_train = ['fraction_white_nh', 'fraction_hispanic', 'fraction_black', \
                    'fraction_other_race', 'fraction_w4yrdeg', 'per_capita_income', \
                    'fraction_evangelical', 'fraction_catholic', 'fraction_mormon', \
                    'fraction_other_religion', 'margin_of_victory_D2016', 'population_density']

# %%
column_target = ['delta_fraction_sanders']

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = all_features
X = data.loc[:,columns_to_train]  #independent columns
y = data.loc[:,column_target]    #target column i.e price range
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-aaf1be4542f2> in <module>
#       8 #apply SelectKBest class to extract top 10 best features
#       9 bestfeatures = SelectKBest(score_func=chi2, k=10)
# ---> 10 fit = bestfeatures.fit(X,y)
#      11 dfscores = pd.DataFrame(fit.scores_)
#      12 dfcolumns = pd.DataFrame(X.columns)
#
# ~/anaconda3/envs/bernie-texas/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~/anaconda3/envs/bernie-texas/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py in chi2(X, y)
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = all_features.loc[:,columns_to_train.append(column_target)]
#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-0c6be8d2b349> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 data = all_features.loc[:,columns_to_train.append(column_target)]
#       5 #get correlations of each features in dataset
#
# ModuleNotFoundError: No module named 'seaborn'
